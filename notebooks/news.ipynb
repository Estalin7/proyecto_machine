# %%
from newspaper import Article

url = "https://peru21.pe/deportes/argentina-vs-inglaterra-en-vivo-goles-resumen-semifinal-mundial-2026-kane-messi/"

article = Article(url)
article.download()
article.parse()

print(f"titulo:",article.title)
# Out:
# titulo: Con goles de Enzo y Lautaro: Argentina venció a Inglaterra y es finalista del Mundial 2026
